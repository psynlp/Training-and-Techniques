# %% [markdown]
# # W2V
# - 기존 통계 기법의 단점을 커버하는 추론기법
# - 맥락 정보를 입력받아 각 단어의 출현 확률을 구함
# - 학습 결과로 얻어진 `가중치`를 `단어의 분산 표현`으로 이용
#
# ![process](img/process.png)
#
# |특징| 통계 기법| 추론기법 |
# |:--------|:--------|:--------|
# |학습| 말뭉치 전체 통계로 1회 학습 | 말뭉치의 일부를 여러번 학습 |
# |새로운 단어 추가| 처음부터 다시 계산 | 추가 학습 가능 |
# |정밀도| 단어의 유사성 |유사성 + 단어 사이의 패턴|
#
# ## CBOW vs Skip-gram
# - 주변 맥락을 통해 단어를 예측 vs 단어를 통해 주변 맥락을 예측
# - Skip-gram이 학습에 더 오랜 시간이 걸리지만 성능이 더 좋음
#
# ![cbow_vs_skipgram](img/cbow_vs_skipgram.png)
#
# ### CBOW
# - $P(w_t | w_{t-1}, w_{t+1})$
#
# ![cbow](img/cbow.png)
#
#
# ### Skip-gram
# - $P(w_{t-1}, w_{t+1} | w_{t})$
#
# ![cbow](img/skipgram.png)
#
# ### W2V의 결과?
# - 맥락을 통해 나올 단어를 예측
# - $W_{in}$, $W_{out}$ 두 종류의 Weight 존재
# - $W_{in}$는 각 행이 각 단어의 분산 표현
# - $W_{out}$는 각 열이 각 단어의 분산 표현
# - 보통 $W_{in}$이 단어의 분산 표현을 잘 나타냄
#
# ![weight](img/weight.png)

# %% [markdown]
# ## 구현
# - 순전파, 역전파를 위해 정형화된 클래스를 이용
#
# ### 입력층 - 은닉층
# - 단어를 적절한 고정된 입력으로 변환해야 학습이 가능
# - One-hot vector 사용
# - 은닉층의 차원이 전체 단어의 차원보다 작아야 차원을 감소하며 단어의 분산을 얻음
#
# ![input1](img/input1.png)
#
# ![inpit3](img/input3.png)
#
# ![inpit4](img/input4.png)

# %%
#!pip install numpy

# %%
#!pip install matplotlib

# %%
import numpy as np

# %%
c = np.array([1, 0, 0, 0, 0, 0, 0])
W = np.random.randn(7, 3)
h = np.matmul(c, W)

print("c: 각 단어의 원핫 벡터")
print(c, "\n")

print("W: 모든 단어를 나타내는 가중치")
print(W, "\n")

print("h: 은닉층 결과(특정 단어의 가중치 추출)")
print(h)
# Out:
# c: 각 단어의 원핫 벡터
# [1 0 0 0 0 0 0]
#
# W: 모든 단어를 나타내는 가중치
# [[ 0.6341437  -0.60125863  2.37405874]
#  [ 0.09874647 -0.24004195  0.17666198]
#  [ 1.51944458  0.86476331  0.32289842]
#  [-0.65748119 -0.53493285  0.86751728]
#  [-0.16886521 -0.65058939 -0.61736574]
#  [ 0.07174646  0.62927708 -0.81633544]
#  [ 0.99839113 -1.36505608  1.74133984]]
#
# h: 은닉층 결과(특정 단어의 가중치 추출)
# [ 0.6341437  -0.60125863  2.37405874]

# %% [markdown]
# ### MatMul 계층 구현

# %%
class MatMul:
    def __init__(self, W):
        self.params = [W]  # 파라미터가 여러개일 수 있어서 리스트 사용
        self.grads = [np.zeros_like(W)]  # 역전파된 결과를 저장하기 위해 사용
        self.x = None  # 역전파시 필요

    # 순전파
    def forward(self, x):
        W, = self.params
        out = np.dot(x, W)
        self.x = x
        return out

    # 역전파
    def backward(self, dout):
        W, = self.params
        dx = np.dot(dout, W.T)
        dW = np.dot(self.x.T, dout)
        self.grads[0][...] = dW  # mutable한 데이터이기 때문에 같은 메모리를 가리키지 않도록 함
        return dx

# %% [markdown]
# ### MatMul 확인
# ![cbow](img/skipgram.png)

# %%
# 샘플 맥락 데이터
c = np.array([[0, 0, 1, 0, 0, 0, 0]])

# 가중치 초기화
W_in = np.random.randn(7, 3)

# 계층 생성
in_layer = MatMul(W_in)

# 순전파
h = in_layer.forward(c)
print(h)
# Out:
# [[-0.43994968 -1.33921933 -1.31235769]]

# %% [markdown]
# ### 은닉층 - 출력층
# - 은닉층 - 출력층 사이의 $W_{out}$은 $W_{in}$를 전치한 shape을 가짐

# %%
# 샘플 맥락 데이터
c = np.array([[0, 0, 1, 0, 0, 0, 0]])

# 가중치 초기화
W_in = np.random.randn(7, 3)
W_out = np.random.randn(3, 7)

# 계층 생성
in_layer = MatMul(W_in)
out_layer = MatMul(W_out)

# 순전파
h = in_layer.forward(c)
s = out_layer.forward(h)
print(s)
# Out:
# [[-2.39479332 -3.07323152 -3.49967342 -0.15048622 -0.13177749  0.04357267
#    2.69458607]]

# %% [markdown]
# ### 출력층 - 확률(Softmax)
# - 출력 결과를 확률로 만들기 위해 Softmax를 이용
# - 오차를 구하기 위해 cross-entropy를 이용하며, 보통 합쳐서 Softmax with Loss 계층 사용
# - 추론시에는 Softmax만 사용해야 함(주의)
# - 오차는 출력과 정답의 차이
#
# ![softmax_with_loss](img/softmax_with_loss.png)

# %%
class SoftmaxWithLoss:
    def __init__(self):
        self.params, self.grads = [], []
        self.y = None  # softmax의 출력
        self.t = None  # 정답 레이블

    # 소프트맥스
    def softmax(self, x):
        if x.ndim == 2:
            x = x - x.max(axis=1, keepdims=True)
            x = np.exp(x)
            x /= x.sum(axis=1, keepdims=True)
        elif x.ndim == 1:
            x = x - np.max(x)
            x = np.exp(x) / np.sum(np.exp(x))

        return x

    # 크로스 엔트로피
    def cross_entropy_error(self, y, t):
        if y.ndim == 1:
            t = t.reshape(1, t.size)
            y = y.reshape(1, y.size)

        # 정답 데이터가 원핫 벡터일 경우 정답 레이블 인덱스로 변환
        if t.size == y.size:
            t = t.argmax(axis=1)

        batch_size = y.shape[0]

        return -np.sum(np.log(y[np.arange(batch_size), t] + 1e-7)) / batch_size

    def forward(self, x, t):
        self.t = t
        self.y = self.softmax(x)

        # 정답 레이블이 원핫 벡터일 경우 정답의 인덱스로 변환
        if self.t.size == self.y.size:
            self.t = self.t.argmax(axis=1)

        loss = self.cross_entropy_error(self.y, self.t)
        return loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]

        dx = self.y.copy()
        dx[np.arange(batch_size), self.t] -= 1
        dx *= dout
        dx = dx / batch_size

        return dx

# %% [markdown]
# ### Skip-gram 모델

# %%
class SimpleSkipGram:
    def __init__(self, vocab_size, hidden_size):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(H, V).astype('f')

        # 계층 생성
        self.in_layer = MatMul(W_in)
        self.out_layer = MatMul(W_out)
        self.loss_layer1 = SoftmaxWithLoss()
        self.loss_layer2 = SoftmaxWithLoss()

        # 모든 가중치와 기울기를 리스트에 모은다.
        layers = [self.in_layer, self.out_layer]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = self.in_layer.forward(target)
        s = self.out_layer.forward(h)
        l1 = self.loss_layer1.forward(s, contexts[:, 0])
        l2 = self.loss_layer2.forward(s, contexts[:, 1])
        loss = l1 + l2
        return loss

    def backward(self, dout=1):
        dl1 = self.loss_layer1.backward(dout)
        dl2 = self.loss_layer2.backward(dout)
        ds = dl1 + dl2
        dh = self.out_layer.backward(ds)
        self.in_layer.backward(dh)
        return None

# %% [markdown]
# ### 학습

# %%
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import preprocess, create_contexts_target, convert_one_hot

# %%
window_size = 1
hidden_size = 100
batch_size = 64
max_epoch = 100

# %%
# text = 'You say goodbye and I say hello.'
with open("train_data.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
corpus, word_to_id, id_to_word = preprocess(text)

# %%
id_to_word
# Out:
# {0: '페이',
#  1: '잘나온다고',
#  2: '모아서',
#  3: '돌려',
#  4: '봤',
#  5: '더',
#  6: '올',
#  7: '내공',
#  8: '나옴',
#  9: '80',
#  10: '개',
#  11: '돌림',
#  12: '저속',
#  13: '거',
#  14: '맞죠',
#  15: '게임',
#  16: '심즈',
#  17: '4',
#  18: '확팩*',
#  19: '스팀',
#  20: '데바',
#  21: '데',
#  22: '돌릴',
#  23: '정도',
#  24: '되고요',
#  25: '어도비',
#  26: '프리미어',
#  27: '에펙*',
#  28: '포토샵',
#  29: '무리',
#  30: '없이',
#  31: '여야',
#  32: '합니다',
#  33: '이런',
#  34: '노트북',
#  35: '얼마',
#  36: '할',
#  37: '라나',
#  38: '150',
#  39: '까지밖에',
#  40: '돈',
#  41: '없는',
#  42: '뎅',
#  43: '참고',
#  44: '게이',
#  45: '밍*',
#  46: '로봇',
#  47: '생기거나',
#  48: 'led',
#  49: '빤짝',
#  50: '거리',
#  51: '건',
#  52: '답글*',
#  53: '볼라',
#  54: '했더니',
#  55: '안눌리*',
#  56: '댓글다는것도',
#  57: '안되나',
#  58: '해서',
#  59: '해봤더니',
#  60: '안눌려*',
#  61: '다른건',
#  62: '다',
#  63: '눌리*',
#  64: '왜',
#  65: '이러는거져',
#  66: '영상',
#  67: '들이요',
#  68: '자꾸',
#  69: '터',
#  70: '확인',
#  71: '해',
#  72: '보라',
#  73: '진짜',
#  74: '짜증나네요',
#  75: '탈퇴',
#  76: '한지',
#  77: '좀',
#  78: '돼서',
#  79: '다시',
#  80: '가입',
#  81: '할라니까',
#  82: '오류',
#  83: '나서',
#  84: '팅겨요',
#  85: '그런것은가요',
#  86: '포스',
#  87: '타입',
#  88: '계정',
#  89: '만들',
#  90: '당시',
#  91: '핸드폰',
#  92: '없어서',
#  93: '동생',
#  94: '것',
#  95: '만들어',
#  96: '사용',
#  97: '했는데',
#  98: '본인',
#  99: '인증',
#  100: '받으려고',
#  101: '하니',
#  102: '제',
#  103: '번호',
#  104: '해도',
#  105: '실패',
#  106: '되는데',
#  107: '기존',
#  108: '개인정보',
#  109: '수정',
#  110: '하는',
#  111: '방법',
#  112: '없나요',
#  113: '성인',
#  114: '맞습니다',
#  115: '알려주실',
#  116: '분',
#  117: '휴대폰',
#  118: '녹음',
#  119: '시',
#  120: '콘서트홀',
#  121: '처럼',
#  122: '어떻게',
#  123: '하나요',
#  124: '국민',
#  125: '자동차',
#  126: '란',
#  127: '무엇',
#  128: '안녕하세요',
#  129: '간편',
#  130: '로그인',
#  131: '설치',
#  132: '아래',
#  133: '아이디',
#  134: '찾기',
#  135: '비밀번호',
#  136: '옆',
#  137: '회색',
#  138: '동그라미',
#  139: '화살표',
#  140: '겹',
#  141: '쳐져',
#  142: '버려',
#  143: '간격',
#  144: '주고싶고',
#  145: '왼쪽',
#  146: '저장',
#  147: '보안',
#  148: '접속',
#  149: '이동',
#  150: '시키고',
#  151: '싶은데',
#  152: '어찌',
#  153: '해야하나요',
#  154: '192',
#  155: '.168',
#  156: '0',
#  157: '.1',
#  158: '여기',
#  159: '들어가서',
#  160: '새로운',
#  161: '관리자',
#  162: '바꾸고',
#  163: '공유',
#  164: '기전체',
#  165: '비번',
#  166: '와이파이',
#  167: '설정',
#  168: '끝',
#  169: '마쳤는데',
#  170: '네트워크',
#  171: '이름',
#  172: 'a',
#  173: '가정',
#  174: '하면',
#  175: '가',
#  176: '뜨고',
#  177: '원래',
#  178: '개방',
#  179: '되어있던',
#  180: 'iptime',
#  181: '이',
#  182: '또',
#  183: '떠서',
#  184: 'b',
#  185: '적용',
#  186: '뜨는데',
#  187: '게',
#  188: '는',
#  189: '인터넷',
#  190: '연결',
#  191: '안되는',
#  192: '상태',
#  193: '구',
#  194: '은',
#  195: '잡히고',
#  196: '됩니다',
#  197: '정말',
#  198: '체적',
#  199: '난국',
#  200: '제발',
#  201: '도와주세요',
#  202: '엄청난',
#  203: '컴맹',
#  204: '빅스',
#  205: '비',
#  206: '버튼',
#  207: '누르면',
#  208: '같이',
#  209: '뜨면서',
#  210: '실행',
#  211: '안됩니다',
#  212: '혹시',
#  213: '해결',
#  214: '있을까요',
#  215: '자바스크립트',
#  216: '공부',
#  217: '중',
#  218: '입니다',
#  219: '다른',
#  220: '사람',
#  221: '만든',
#  222: '소스',
#  223: '연구',
#  224: '하면서',
#  225: '좋을',
#  226: '듯',
#  227: '한데요',
#  228: '간단한',
#  229: '많은',
#  230: '사이트',
#  231: '너무',
#  232: '복잡한',
#  233: '하기',
#  234: '힘들것',
#  235: '같고요',
#  236: '사진',
#  237: '본떠서',
#  238: '캐릭터',
#  239: '제작',
#  240: '해주실수있는',
#  241: '구합',
#  242: '니',
#  243: '작업',
#  244: '물',
#  245: '보고',
#  246: '결정',
#  247: '하고싶네요',
#  248: '카톡',
#  249: 'menime',
#  250: '느낌',
#  251: '원합니다',
#  252: '작동',
#  253: '하던',
#  254: '어플',
#  255: '지금',
#  256: '앱',
#  257: '인벤',
#  258: '코딩',
#  259: '화면',
#  260: '들어가면',
#  261: 'internal',
#  262: 'error',
#  263: '버그',
#  264: '리포트',
#  265: '뜨네요',
#  266: '이상한건',
#  267: '가요',
#  268: '임시',
#  269: '파일',
#  270: '계속',
#  271: '순식간',
#  272: '불어나서',
#  273: '100',
#  274: '가가',
#  275: '넘어',
#  276: '버렸어요',
#  277: '바이러스',
#  278: '먹은',
#  279: '건지',
#  280: '삭제',
#  281: '하려고',
#  282: '들어가도',
#  283: '도대체',
#  284: '뭐',
#  285: '기가를',
#  286: '잡아먹은',
#  287: '커다란',
#  288: '용량',
#  289: '뜨지가',
#  290: '않네요',
#  291: '단순한',
#  292: '검색',
#  293: '기록',
#  294: '절대',
#  295: '아닙니다',
#  296: '문제',
#  297: '있는거',
#  298: '같은데',
#  299: '도움',
#  300: '주세요',
#  301: 'window',
#  302: 'old',
#  303: '업데이트',
#  304: '기',
#  305: '되는',
#  306: '지웠는데도',
#  307: '똑같습니다',
#  308: 'temp',
#  309: '폴더',
#  310: '아니에요',
#  311: 'q',
#  312: '6',
#  313: '사용자',
#  314: '보시다시피',
#  315: '카메라',
#  316: '깨져',
#  317: '버렸는데',
#  318: '수리',
#  319: '대충',
#  320: '나오나요',
#  321: '윈도우',
#  322: '되어',
#  323: '있는',
#  324: 'ssd',
#  325: '위해',
#  326: '추가',
#  327: '했던',
#  328: '하드디스크',
#  329: '가끔',
#  330: '끊겨서',
#  331: '인식',
#  332: '못',
#  333: '리부팅',
#  334: '괜찮아지는',
#  335: '증상',
#  336: '점점',
#  337: '빈번',
#  338: '해져서',
#  339: '이번',
#  340: '교체',
#  341: '했습니다',
#  342: '깔려있는',
#  343: '그대로',
#  344: '되었던',
#  345: '된',
#  346: '하드',
#  347: '빼고',
#  348: '동일',
#  349: '제품',
#  350: '했는데요',
#  351: '후',
#  352: '등',
#  353: '전혀',
#  354: '발생',
#  355: '하지',
#  356: '않는데',
#  357: '간',
#  358: '헐',
#  359: '적',
#  360: '자동',
#  361: '자주',
#  362: '아니고',
#  363: '12시간',
#  364: '기준',
#  365: '한',
#  366: '두',
#  367: '번',
#  368: '일것',
#  369: '같네요',
#  370: '처음',
#  371: '여러',
#  372: '프로그램',
#  373: '돌리면',
#  374: '그',
#  375: '런가',
#  376: '했',
#  377: '이전',
#  378: '다나',
#  379: '와에서',
#  380: '최저',
#  381: '가로',
#  382: '구해',
#  383: '조립',
#  384: '했었는데',
#  385: '아는',
#  386: '형님',
#  387: '컴퓨터',
#  388: '모바일',
#  389: '리니지',
#  390: '하신다고',
#  391: '하시는데',
#  392: '렉',
#  393: '심해서',
#  394: '하나',
#  395: '구매',
#  396: '하십니다',
#  397: '9700',
#  398: 'k',
#  399: '2060',
#  400: '16',
#  401: 'g',
#  402: '화이트',
#  403: '색상',
#  404: '커스튬*',
#  405: '해놨는데',
#  406: '보시더니',
#  407: '제거',
#  408: '똑같은',
#  409: '동일한',
#  410: '조건',
#  411: '120',
#  412: '해달라',
#  413: '정확히',
#  414: '기억',
#  415: '안나는데',
#  416: '모니터',
#  417: '포함',
#  418: '주변기기',
#  419: '180',
#  420: '넘게',
#  421: '준것으로',
#  422: '하는데요',
#  423: '아마',
#  424: '램',
#  425: '쿨러',
#  426: '메인보드',
#  427: '써서',
#  428: 'gskill',
#  429: '로얄',
#  430: '감성',
#  431: '투자',
#  432: '서요',
#  433: '필요',
#  434: '없으시다고',
#  435: '동영상',
#  436: '편집',
#  437: '앱스토어',
#  438: '추천',
#  439: '부탁드립니다',
#  440: '아이폰',
#  441: '정품*',
#  442: '케이블',
#  443: '잘',
#  444: '고장',
#  445: '나나',
#  446: '아까',
#  447: '아침',
#  448: '충전',
#  449: '됐는데',
#  450: '이제',
#  451: '자려고',
#  452: '하니까',
#  453: '갑자기',
#  454: '표시',
#  455: '안',
#  456: '됐다가',
#  457: '몰라',
#  458: '다이소',
#  459: '충전기',
#  460: '해봤는데',
#  461: '돼네요',
#  462: '외관',
#  463: '크게',
#  464: '나무랄',
#  465: '대가',
#  466: '깨끗한데',
#  467: '확확',
#  468: '잡아',
#  469: '빼서',
#  470: '걸',
#  471: '까요',
#  472: '있다가',
#  473: '들어갈까',
#  474: '싶어서',
#  475: '로그아웃',
#  476: '했거든요',
#  477: '그리고',
#  478: '이로',
#  479: '하는데',
#  480: '돼요',
#  481: '떠요',
#  482: '아니라',
#  483: '어쩌다',
#  484: '보니',
#  485: '생긴',
#  486: '거든용',
#  487: '해야',
#  488: '할까',
#  489: '요',
#  490: '카카오페이지',
#  491: '캐쉬',
#  492: '결재',
#  493: '체크카드',
#  494: '연동',
#  495: '되어있는데',
#  496: '들어있는',
#  497: '금액',
#  498: '결제',
#  499: '하기를',
#  500: '눌렀는데',
#  501: '되었습니다',
#  502: '텔레뱅킹*',
#  503: '잔액',
#  504: '조회',
#  505: '했을',
#  506: '때',
#  507: '분명',
#  508: '있었는데',
#  509: '했어요',
#  510: '걸까',
#  511: '고객',
#  512: '이미',
#  513: '애드센스',
#  514: '있습니다',
#  515: '관심',
#  516: '가져',
#  517: '주셔서',
#  518: '감사합니다',
#  519: '가능한',
#  520: '계정은',
#  521: '1',
#  522: '인당',
#  523: '허용',
#  524: '하려면',
#  525: '다음',
#  526: '수행',
#  527: '하세요',
#  528: '',
#  529: '.',
#  530: '.@gmail',
#  531: '.com',
#  532: '와',
#  533: '과',
#  534: '액세스',
#  535: '수',
#  536: '없다면',
#  537: '문제해결',
#  538: '도구',
#  539: '내',
#  540: '절차',
#  541: '따르세요',
#  542: '또는',
#  543: '2',
#  544: '센터',
#  545: '도움말',
#  546: '해지',
#  547: '따라',
#  548: '봅니다',
#  549: '곧',
#  550: '광고',
#  551: '게재',
#  552: '하실',
#  553: '있기를',
#  554: '바랍니다',
#  555: '에스크',
#  556: '5',
#  557: '있다는데',
#  558: '치라',
#  559: '쳐서',
#  560: '들어갔더니',
#  561: '그냥',
#  562: '돌아오던데',
#  563: '팔',
#  564: '임',
#  565: '갤럭시',
#  566: 's',
#  567: '10',
#  568: '전면',
#  569: '둘다',
#  570: 'uhd',
#  571: '3840',
#  572: 'x',
#  573: '2160',
#  574: '지원',
#  575: '그러면',
#  576: '찍든',
#  577: '후면*',
#  578: '화질',
#  579: '건가',
#  580: '크루',
#  581: '중이',
#  582: '길',
#  583: '사서',
#  584: '맞춘',
#  585: '채',
#  586: '유',
#  587: '플레이',
#  588: '할려는데',
#  589: '맞게치고',
#  590: '깔아도',
#  591: '방화벽',
#  592: '해보고',
#  593: '다해',
#  594: '봤는데',
#  595: '안되네요',
#  596: '이러나요',
#  597: '오프라인',
#  598: '전환',
#  599: '하기전에',
#  600: '최소',
#  601: '1회',
#  602: '온',
#  603: '모드',
#  604: '무슨',
#  605: '로그인오류',
#  606: '그게',
#  607: '뒤져',
#  608: '유튜브',
#  609: '틀',
#  610: '외국',
#  611: '오래되서',
#  612: '알려주세요',
#  613: '산지',
#  614: '주가',
#  615: '되어가는데',
#  616: '한판',
#  617: '위너',
#  618: '공식',
#  619: '양도',
#  620: '받았는데',
#  621: '인',
#  622: '존',
#  623: '들어가는지',
#  624: '모르겠네요',
#  625: '50',
#  626: '컴',
#  627: '폰',
#  628: '연결하는데',
#  629: '지난번',
#  630: '연결하다가',
#  631: '랙걸려*',
#  632: '시도',
#  633: '되면서',
#  634: '루트',
#  635: '없다느니',
#  636: '안되고',
#  637: '체팅*',
#  638: '있다면',
#  639: '알려주시고요',
#  640: '보통',
#  641: '십초',
#  642: '지연',
#  643: '시켰다가',
#  644: '되는건데',
#  645: '일이',
#  646: '거의',
#  647: '달동',
#  648: '이러는데',
#  649: '분동',
#  650: '차단',
#  651: '가능한지',
#  652: '모두',
#  653: '했는데도',
#  654: '같은',
#  655: '반응',
#  656: '이쁜걸루*',
#  657: 'h',
#  658: '숫자',
#  659: '그것',
#  660: '나오네요',
#  661: '박문각',
#  662: '강의',
#  663: '자료',
#  664: 'swf',
#  665: '를',
#  666: '아이패드',
#  667: '넣어서',
#  668: '굿',
#  669: '노트',
#  670: '열어서',
#  671: '함께',
#  672: '보며',
#  673: '도저히',
#  674: '모르겠어요',
#  675: '이렇게',
#  676: '노랗게',
#  677: '초록',
#  678: '뜨구요',
#  679: '아무런',
#  680: '터치',
#  681: '까맣게',
#  682: '꺼져있을',
#  683: '많습니다',
#  684: '소리',
#  685: '나는데',
#  686: '전원',
#  687: '끌때*',
#  688: '나',
#  689: '진동',
#  690: '절대로',
#  691: '있는거져',
#  692: '티브로드',
#  693: '할려고',
#  694: '명의',
#  695: '사람이름',
#  696: '고',
#  697: '연락',
#  698: '안되거든요',
#  699: '없을까요',
#  700: '꼭',
#  701: '알려세요',
#  702: '글자',
#  703: '몇개',
#  704: '문서',
#  705: '같은것도',
#  706: '밑',
#  707: '한글',
#  708: '아이콘',
#  709: '뜨',
#  710: '기도',
#  711: '이러는건',
#  712: '걸린거에요',
#  713: '에어팟',
#  714: '한쪽',
#  715: '잃어버려서',
#  716: '애플',
#  717: '재구매',
#  718: '안되서',
#  719: '일렬',
#  720: '해보니',
#  721: '다르네요',
#  722: '재구',
#  723: '매하',
#  724: '정확하신',
#  725: '분만',
#  726: '답',
#  727: '해주세요',
#  728: '멤',
#  729: '버스',
#  730: '문상',
#  731: '2천원',
#  732: '쿠폰',
#  733: '자리',
#  734: '제대로',
#  735: '쳐도',
#  736: '상품권',
#  737: '됐다고',
#  738: '보',
#  739: '16~17',
#  740: '거나',
#  741: '막친*',
#  742: '18',
#  743: '자리는',
#  744: '0원',
#  745: '잘만',
#  746: '이러죠',
#  747: '매크로',
#  748: '답변',
#  749: '직접',
#  750: '해보신',
#  751: '그래픽카드',
#  752: '충돌',
#  753: '같습니다',
#  754: '전',
#  755: '맞췄습니다',
#  756: '호환*',
#  757: '안된다며',
#  758: '박격포',
#  759: '450',
#  760: '했구요',
#  761: '부팅',
#  762: '바로',
#  763: '시작',
#  764: '동시',
#  765: '켜지는',
#  766: '안되었다고',
#  767: '뜹니다',
#  768: '20초',
#  769: '괜찮아지구요',
#  770: '들어가게되',
#  771: '면',
#  772: '리그',
#  773: '오브',
#  774: '레전드',
#  775: '경우',
#  776: '로딩',
#  777: '지나가고',
#  778: '3분',
#  779: '아예',
#  780: '가버립니다',
#  781: '시간',
#  782: '지나면',
#  783: '판',
#  784: '없지만',
#  785: '끊기구요',
#  786: '대해',
#  787: '모르는',
#  788: '였는데',
#  789: '해보려고',
#  790: '일주일',
#  791: '800',
#  792: 'dpi',
#  793: '직감',
#  794: '.95',
#  795: '쓰고',
#  796: '있는데',
#  797: '해주시면',
#  798: '감사하겠습니다',
#  799: '데스크탑',
#  800: '연결해서',
#  801: '쓸수있나요',
#  802: '움짤',
#  803: '좋구요',
#  804: '문구',
#  805: '사랑니',
#  806: '저',
#  807: '연락처',
#  808: '등록',
#  809: '아니면',
#  810: '찾거나',
#  811: '상대방',
#  812: '하고',
#  813: '뜨나요',
#  814: '크기',
#  815: '나오는',
#  816: '어덯*',
#  817: '맞추나요',
#  818: '보는것같이',
#  819: '중앙',
#  820: '나오는데',
#  821: '원본',
#  822: '맞추고싶어요',
#  823: '중고차',
#  824: '구입',
#  825: '했는대',
#  826: '트립*',
#  827: '그랜저',
#  828: '2012',
#  829: '아이나비',
#  830: '모텔',
#  831: 'r',
#  832: '300',
#  833: '주',
#  834: '디오스',
#  835: '트랩',
#  836: '알아보니',
#  837: '망해서',
#  838: '받을수가',
#  839: '업다네요',
#  840: '가지',
#  841: '계',
#  842: '신분',
#  843: '부탁',
#  844: '드립니다',
#  845: '멜론',
#  846: '엄마',
#  847: '하고나서',
#  848: '카카오',
#  849: '톡',
#  850: '하지도',
#  851: '않았는데',
#  852: '저희',
#  853: '되어있더라고요',
#  854: '작년',
#  855: '하다가',
#  856: '사기',
#  857: '당했는데',
#  858: '최근',
#  859: '활동',
#  860: '있나요',
#  861: '당한',
#  862: '있나여',
#  863: '아는게',
#  864: '있으면',
#  865: '페북',
#  866: '인스타',
#  867: '전화번호',
#  868: '주소',
#  869: '같은거',
#  870: '남겨주세요',
#  871: '생각',
#  872: '열',
#  873: '받네요',
#  874: '제목',
#  875: 'url',
#  876: 'utm',
#  877: 'source',
#  878: 'medium',
#  879: 'campaign',
#  880: 'content',
#  881: '덧붙이는',
#  882: '이유',
#  883: '궁금합니다',
#  884: '또한',
#  885: '각자',
#  886: '역할',
#  887: '하는지도',
#  888: '궁금해요',
#  889: '기본',
#  890: '더하면',
#  891: '클릭',
#  892: '수집',
#  893: '만약',
#  894: '그렇다면',
#  895: '개인',
#  896: '홈페이지',
#  897: '블로그',
#  898: '올렸을',
#  899: '불이익',
#  900: '정보',
#  901: '빼',
#  902: '간다거나',
#  903: '해킹',
#  904: '모로',
#  905: '궁금하네요',
#  906: '친절한',
#  907: '기다리고',
#  908: '있겠습니다',
#  909: '했었던',
#  910: '되잖아요',
#  911: '특정',
#  912: '누를',
#  913: '뜨지',
#  914: '않게',
#  915: '했으면',
#  916: '좋겠는데',
#  917: '이해',
#  918: '상황',
#  919: '자세히',
#  920: '설명',
#  921: '드*',
#  922: '빠뜨려서',
#  923: '말리는',
#  924: '동안',
#  925: '공기',
#  926: '유심',
#  927: '있거든요',
#  928: '그러다가',
#  929: '어쩔',
#  930: '새로',
#  931: '팠어요',
#  932: '근데',
#  933: '메일',
#  934: '구독',
#  935: '대놓고',
#  936: '비밀',
#  937: '취미',
#  938: '나타내서',
#  939: '야한거',
#  940: '아니',
#  941: 'skt',
#  942: '개는',
#  943: '두고',
#  944: 'kt',
#  945: '옮기면',
#  946: '되나요',
#  947: '메세지',
#  948: '무시',
#  949: '옵션',
#  950: '떠야하는데',
#  951: '해하',
#  952: '위치',
#  953: '추적',
#  954: '젠리*',
#  955: '얼음',
#  956: '해놓으면',
#  957: '법',
#  958: '들키면',
#  959: '뻘쭘*',
#  960: '할거',
#  961: '같아서',
#  962: '소문',
#  963: '모르는데',
#  964: '배터리',
#  965: '안줄거나',
#  966: '어떤',
#  967: '신호',
#  968: '알수',
#  969: '간접',
#  970: '알',
#  971: '시키면',
#  972: '페이지',
#  973: '자나여',
#  974: '콘*',
#  975: '트롤',
#  976: '엔터*',
#  977: '총',
#  978: '3',
#  979: '되었어요',
#  980: '단축키',
#  981: '뭔가',
#  982: '지니',
#  983: '스밍*',
#  984: '횟수',
#  985: '단기간',
#  986: '늘려야',
#  987: '곡',
#  988: '반복',
#  989: '재생',
#  990: '안된다고',
#  991: '들었는데',
#  992: '돼도',
#  993: '들은',
#  994: '올라가나요',
#  995: '그리구',
#  996: '무음',
#  997: '놔도',
#  998: '넷플릭스',
#  999: '시청',
#  ...}

# %%
vocab_size = len(word_to_id)
contexts, target = create_contexts_target(corpus, window_size)
target = convert_one_hot(target, vocab_size)
contexts = convert_one_hot(contexts, vocab_size)

model = SimpleSkipGram(vocab_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

word_vecs = model.word_vecs
# Out:
# | 에폭 1 |  반복 1 / 476 | 시간 34[s] | 손실 17.83
# | 에폭 1 |  반복 21 / 476 | 시간 37[s] | 손실 17.83
# | 에폭 1 |  반복 41 / 476 | 시간 40[s] | 손실 17.83
# | 에폭 1 |  반복 61 / 476 | 시간 44[s] | 손실 17.83
# | 에폭 1 |  반복 81 / 476 | 시간 47[s] | 손실 17.83
# | 에폭 1 |  반복 101 / 476 | 시간 51[s] | 손실 17.82
# | 에폭 1 |  반복 121 / 476 | 시간 54[s] | 손실 17.79
# | 에폭 1 |  반복 141 / 476 | 시간 58[s] | 손실 17.76
# | 에폭 1 |  반복 161 / 476 | 시간 61[s] | 손실 17.70
# | 에폭 1 |  반복 181 / 476 | 시간 64[s] | 손실 17.61
# | 에폭 1 |  반복 201 / 476 | 시간 66[s] | 손실 17.50
# | 에폭 1 |  반복 221 / 476 | 시간 69[s] | 손실 17.39
# | 에폭 1 |  반복 241 / 476 | 시간 71[s] | 손실 17.34
# | 에폭 1 |  반복 261 / 476 | 시간 73[s] | 손실 17.22
# | 에폭 1 |  반복 281 / 476 | 시간 76[s] | 손실 17.11
# | 에폭 1 |  반복 301 / 476 | 시간 78[s] | 손실 17.03
# | 에폭 1 |  반복 321 / 476 | 시간 80[s] | 손실 16.89
# | 에폭 1 |  반복 341 / 476 | 시간 83[s] | 손실 16.81
# | 에폭 1 |  반복 361 / 476 | 시간 85[s] | 손실 16.80
# | 에폭 1 |  반복 381 / 476 | 시간 88[s] | 손실 16.71
# | 에폭 1 |  반복 401 / 476 | 시간 90[s] | 손실 16.69
# | 에폭 1 |  반복 421 / 476 | 시간 93[s] | 손실 16.65
# | 에폭 1 |  반복 441 / 476 | 시간 95[s] | 손실 16.60
# | 에폭 1 |  반복 461 / 476 | 시간 98[s] | 손실 16.58
# | 에폭 2 |  반복 1 / 476 | 시간 115[s] | 손실 16.59
# | 에폭 2 |  반복 21 / 476 | 시간 117[s] | 손실 16.14
# | 에폭 2 |  반복 41 / 476 | 시간 119[s] | 손실 16.09
# | 에폭 2 |  반복 61 / 476 | 시간 122[s] | 손실 16.08
# | 에폭 2 |  반복 81 / 476 | 시간 124[s] | 손실 15.99
# | 에폭 2 |  반복 101 / 476 | 시간 126[s] | 손실 15.95
# | 에폭 2 |  반복 121 / 476 | 시간 128[s] | 손실 16.03
# | 에폭 2 |  반복 141 / 476 | 시간 130[s] | 손실 15.91
# | 에폭 2 |  반복 161 / 476 | 시간 133[s] | 손실 16.01
# | 에폭 2 |  반복 181 / 476 | 시간 135[s] | 손실 15.93
# | 에폭 2 |  반복 201 / 476 | 시간 137[s] | 손실 15.95
# | 에폭 2 |  반복 221 / 476 | 시간 139[s] | 손실 15.96
# | 에폭 2 |  반복 241 / 476 | 시간 142[s] | 손실 15.83
# | 에폭 2 |  반복 261 / 476 | 시간 145[s] | 손실 15.94
# | 에폭 2 |  반복 281 / 476 | 시간 148[s] | 손실 15.90
# | 에폭 2 |  반복 301 / 476 | 시간 151[s] | 손실 15.84
# | 에폭 2 |  반복 321 / 476 | 시간 153[s] | 손실 15.87
# | 에폭 2 |  반복 341 / 476 | 시간 156[s] | 손실 15.81
# | 에폭 2 |  반복 361 / 476 | 시간 158[s] | 손실 15.83
# | 에폭 2 |  반복 381 / 476 | 시간 161[s] | 손실 15.69
# | 에폭 2 |  반복 401 / 476 | 시간 163[s] | 손실 15.77
# | 에폭 2 |  반복 421 / 476 | 시간 165[s] | 손실 15.82
# | 에폭 2 |  반복 441 / 476 | 시간 168[s] | 손실 15.80
# | 에폭 2 |  반복 461 / 476 | 시간 170[s] | 손실 15.78
# | 에폭 3 |  반복 1 / 476 | 시간 182[s] | 손실 15.76
# | 에폭 3 |  반복 21 / 476 | 시간 184[s] | 손실 15.55
# | 에폭 3 |  반복 41 / 476 | 시간 186[s] | 손실 15.47
# | 에폭 3 |  반복 61 / 476 | 시간 188[s] | 손실 15.54
# | 에폭 3 |  반복 81 / 476 | 시간 191[s] | 손실 15.39
# | 에폭 3 |  반복 101 / 476 | 시간 193[s] | 손실 15.41
# | 에폭 3 |  반복 121 / 476 | 시간 195[s] | 손실 15.27
# | 에폭 3 |  반복 141 / 476 | 시간 197[s] | 손실 15.40
# | 에폭 3 |  반복 161 / 476 | 시간 199[s] | 손실 15.42
# | 에폭 3 |  반복 181 / 476 | 시간 202[s] | 손실 15.36
# | 에폭 3 |  반복 201 / 476 | 시간 204[s] | 손실 15.47
# | 에폭 3 |  반복 221 / 476 | 시간 207[s] | 손실 15.38
# | 에폭 3 |  반복 241 / 476 | 시간 209[s] | 손실 15.41
# | 에폭 3 |  반복 261 / 476 | 시간 211[s] | 손실 15.35
# | 에폭 3 |  반복 281 / 476 | 시간 214[s] | 손실 15.30
# | 에폭 3 |  반복 301 / 476 | 시간 216[s] | 손실 15.46
# | 에폭 3 |  반복 321 / 476 | 시간 218[s] | 손실 15.42
# | 에폭 3 |  반복 341 / 476 | 시간 220[s] | 손실 15.44
# | 에폭 3 |  반복 361 / 476 | 시간 223[s] | 손실 15.41
# | 에폭 3 |  반복 381 / 476 | 시간 225[s] | 손실 15.39
# | 에폭 3 |  반복 401 / 476 | 시간 227[s] | 손실 15.15
# | 에폭 3 |  반복 421 / 476 | 시간 230[s] | 손실 15.46
# | 에폭 3 |  반복 441 / 476 | 시간 232[s] | 손실 15.43
# | 에폭 3 |  반복 461 / 476 | 시간 234[s] | 손실 15.40
# | 에폭 4 |  반복 1 / 476 | 시간 241[s] | 손실 15.30
# | 에폭 4 |  반복 21 / 476 | 시간 243[s] | 손실 15.14
# | 에폭 4 |  반복 41 / 476 | 시간 246[s] | 손실 15.02
# | 에폭 4 |  반복 61 / 476 | 시간 248[s] | 손실 15.12
# | 에폭 4 |  반복 81 / 476 | 시간 250[s] | 손실 15.07
# | 에폭 4 |  반복 101 / 476 | 시간 252[s] | 손실 15.07
# | 에폭 4 |  반복 121 / 476 | 시간 254[s] | 손실 15.16
# | 에폭 4 |  반복 141 / 476 | 시간 257[s] | 손실 15.08
# | 에폭 4 |  반복 161 / 476 | 시간 259[s] | 손실 14.89
# | 에폭 4 |  반복 181 / 476 | 시간 261[s] | 손실 14.92
# | 에폭 4 |  반복 201 / 476 | 시간 263[s] | 손실 15.09
# | 에폭 4 |  반복 221 / 476 | 시간 265[s] | 손실 14.85
# | 에폭 4 |  반복 241 / 476 | 시간 268[s] | 손실 14.92
# | 에폭 4 |  반복 261 / 476 | 시간 270[s] | 손실 15.16
# | 에폭 4 |  반복 281 / 476 | 시간 272[s] | 손실 14.88
# | 에폭 4 |  반복 301 / 476 | 시간 274[s] | 손실 14.99
# | 에폭 4 |  반복 321 / 476 | 시간 276[s] | 손실 14.92
# | 에폭 4 |  반복 341 / 476 | 시간 279[s] | 손실 14.98
# | 에폭 4 |  반복 361 / 476 | 시간 281[s] | 손실 15.02
# | 에폭 4 |  반복 381 / 476 | 시간 283[s] | 손실 14.92
# | 에폭 4 |  반복 401 / 476 | 시간 286[s] | 손실 14.93
# | 에폭 4 |  반복 421 / 476 | 시간 288[s] | 손실 14.99
# | 에폭 4 |  반복 441 / 476 | 시간 290[s] | 손실 15.00
# | 에폭 4 |  반복 461 / 476 | 시간 292[s] | 손실 14.96
# | 에폭 5 |  반복 1 / 476 | 시간 298[s] | 손실 14.97
# | 에폭 5 |  반복 21 / 476 | 시간 301[s] | 손실 14.61
# | 에폭 5 |  반복 41 / 476 | 시간 303[s] | 손실 14.57
# | 에폭 5 |  반복 61 / 476 | 시간 305[s] | 손실 14.57
# | 에폭 5 |  반복 81 / 476 | 시간 308[s] | 손실 14.56
# | 에폭 5 |  반복 101 / 476 | 시간 310[s] | 손실 14.52
# | 에폭 5 |  반복 121 / 476 | 시간 312[s] | 손실 14.62
# | 에폭 5 |  반복 141 / 476 | 시간 314[s] | 손실 14.69
# | 에폭 5 |  반복 161 / 476 | 시간 316[s] | 손실 14.67
# | 에폭 5 |  반복 181 / 476 | 시간 319[s] | 손실 14.61
# | 에폭 5 |  반복 201 / 476 | 시간 321[s] | 손실 14.63
# | 에폭 5 |  반복 221 / 476 | 시간 323[s] | 손실 14.62
# | 에폭 5 |  반복 241 / 476 | 시간 325[s] | 손실 14.65
# | 에폭 5 |  반복 261 / 476 | 시간 327[s] | 손실 14.62
# | 에폭 5 |  반복 281 / 476 | 시간 329[s] | 손실 14.63
# | 에폭 5 |  반복 301 / 476 | 시간 332[s] | 손실 14.62
# | 에폭 5 |  반복 321 / 476 | 시간 334[s] | 손실 14.67
# | 에폭 5 |  반복 341 / 476 | 시간 336[s] | 손실 14.58
# | 에폭 5 |  반복 361 / 476 | 시간 338[s] | 손실 14.43
# | 에폭 5 |  반복 381 / 476 | 시간 341[s] | 손실 14.46
# | 에폭 5 |  반복 401 / 476 | 시간 343[s] | 손실 14.69
# | 에폭 5 |  반복 421 / 476 | 시간 345[s] | 손실 14.49
# | 에폭 5 |  반복 441 / 476 | 시간 347[s] | 손실 14.62
# | 에폭 5 |  반복 461 / 476 | 시간 349[s] | 손실 14.54
# | 에폭 6 |  반복 1 / 476 | 시간 354[s] | 손실 14.37
# | 에폭 6 |  반복 21 / 476 | 시간 356[s] | 손실 14.24

# %% [markdown]
# ## 단어 분산 표현 저장 및 확인

# %%
out_v = open('ko-vecs.tsv', 'w', encoding='utf-8')
out_m = open('ko-meta.tsv', 'w', encoding='utf-8')

for word_id, word in id_to_word.items():
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in word_vecs[word_id]]) + "\n")
out_v.close()
out_m.close()

# %% [markdown]
# [Tensor board](http://projector.tensorflow.org/)

# %% [markdown]
# ## W2V의 개선
#
# ### 문제점
# - W2V는 $W_{in}$과 $W_{out}$을 학습함
# - 각각은 $V x N$, $N x V$의 크기
#     - 단어수 : 10만개
#     - 임베딩 차원 : 100차원
#         - 2000만개(2 x 10만 x 100)의 값을 구해야 함
# - 단어가 늘어날 수록 계산량이 폭발적으로 증가
#
# ### 해결 방안
#
# #### 1. MatMul 연산 개선
# - W2V에서 사용하는 MatMul 연산은 단순 행 혹은 열을 추출하는 연산
# - Numpy를 이용한다면 해당 단어의 행을 추출하는 작업으로 대체 가능
#
# #### 2. Negative Sampling(확률 계산의 효율성을 위해)
# - 하나의 단어에 대한 Softmax 계산은 $y_k = \frac{\exp(S_k)}{\sum_{i=1}^{n} \exp(S_{i})}$
# - Corpus가 커지면 연산량이 폭발적으로 증가
# - 모든 단어가 아닌 일부 단어만 뽑아서 학습
# - positive sample과 negative sample 일부를 사용하여 학습
# - Negative sampling은 corpus에서 각 단어의 출현 횟수를 구한 확률분포를 토대로 사용
# - Corpus에서 자주 등장하는 단어는 자주 선택되어 자주 업데이트 됨
# - 일반적으로 5~20개 정도의 negative sample을 이용
#
# #### 3. Subsamplig frequent words(저빈도 단어에게 학습의 기회를 많이 주기 위해)
# - 고빈도 단어는 업데이트가 많이 될 수 있음
# - 'the', 'a', 'in' 등과 같은 고빈도 단어들의 학습량을 확률적으로 줄이고 저빈도 단어의 학습 기회를 줄 필요 존재
# - 단어$w$는 $P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}}$의 확률로 학습에서 제외되며, $t$는 $10^{-5}$ 정도가 적절

# %% [markdown]
# ### 이런 것도 존재
# - [Binary Classification](https://github.com/sucream/cogpsi/blob/master/RL/W2/nlp/week_02.ipynb)

# %% [markdown]
# ## 결론
# - 잘 만들어져 있는 라이브러리를 이용하자..

# %% [markdown]
# ## 참고
# - [밑바닥부터 시작하는 딥러닝2](https://github.com/WegraLee/deep-learning-from-scratch-2)
# - [gichang.lee - Word2Vec의 학습 방식](https://ratsgo.github.io/from%20frequency%20to%20semantics/2017/03/30/word2vec/)
# - [coursera - Natural Language Processing in TensorFlow](https://www.coursera.org/learn/natural-language-processing-tensorflow)
